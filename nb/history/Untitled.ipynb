# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_tabel("./errdis",sep='\t',header=["vendor","err","pv"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-2-0d6da71008a9> in <module>()
# ----> 1 df=pd.read_tabel("./errdis",sep='\t',header=["vendor","err","pv"])
#
# AttributeError: 'module' object has no attribute 'read_tabel'

# %%
df=pd.read_table("./errdis",sep='\t',header=["vendor","err","pv"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-3-ee305a4ca04d> in <module>()
# ----> 1 df=pd.read_table("./errdis",sep='\t',header=["vendor","err","pv"])
#
# ...

# %%
df=pd.read_tabel("./errdis",sep='\t',header=None,usecols=["vendor","err","pv"])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-e4679104eed5> in <module>()
# ----> 1 df=pd.read_tabel("./errdis",sep='\t',header=None,usecols=["vendor","err","pv"])
#
# AttributeError: 'module' object has no attribute 'read_tabel'

# %%
df=pd.read_table("./errdis",sep='\t',header=None,usecols=["vendor","err","pv"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-df81a59ec071> in <module>()
# ----> 1 df=pd.read_table("./errdis",sep='\t',header=None,usecols=["vendor","err","pv"])
#
# ...

# %%
df=pd.read_tabel("./errdis",sep='\t',header=None)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-33471fe75dc7> in <module>()
# ----> 1 df=pd.read_tabel("./errdis",sep='\t',header=None)
#
# AttributeError: 'module' object has no attribute 'read_tabel'

# %%
df=pd.read_table("./errdis",sep='\t',header=None)

# %%
df=pd.read_table("./errdis",sep='\t',header=None,names=["vendor","err","pv"])

# %%
df
# Out:
#      vendor  err         pv
# 0        64   37    1687849
# 1         0    5         11
# 2        33    0        215
# 3        33    1         43
# 4        33    8          2
# 5        61  152   88407772
# 6        61  153    2735253
# 7         1   -1        960
# 8         1    0   36252774
# 9         1    1      18030
# 10       33   20          4
# 11        1    8    1452250
# 12       63  104         41
# 13        1    9   61448494
# 14       63  106       2031
# 15       63  107         10
# 16        1   14   15078438
# 17       34    0         26
# 18       34    1          1
# 19        1   16    1730632
# 20       31   98   15539845
# 21        1   20   89694116
# 22        1   21    3636738
# 23       31  101   47049900
# 24       31  104   35273478
# 25       31  105        732
# 26        1   27      25740
# 27       31  106    5887748
# 28        1   28  134966787
# 29        2   -1       4803
# ..      ...  ...        ...
# 321      27   14      22694
# ...

# %%
df.groupby('vendor').sum()
# Out:
#          err          pv
# vendor
# 0          5          11
# 1       1095   863061992
# 2       1662  2800098527
# 3        737   271607660
# 4        787      474661
# 5       1760   298238532
# 8       1176    31547706
# 9       2180  3166109748
# 10      1152   921307925
# 13       438     3218257
# 14       761   204042171
# 15      1388   562506357
# 16       512   308049372
# 20       618     1317140
# 21      1271  1965229277
# 24       784  1503452801
# 27       135       22703
# 31       927  1317952939
# 33        29         264
# 34         1          27
# 37      1103    56639950
# 38       690      907002
# 40         0           5
# 54       692     2099583
# 56         0          43
# 57       361    98163342
# 58       349    51549866
# 61       362   224950724
# 63       317        2082
# 64       587   254673003
# 68       349   114382790
# 70       349   234322848

# %%
df.groupby('vendor',"err").sum()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-9129bb2af946> in <module>()
# ----> 1 df.groupby('vendor',"err").sum()
#
# /home/xiangrong/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze)
#    3744         if level is None and by is None:
#    3745             raise TypeError("You have to supply one of 'by' and 'level'")
# -> 3746         axis = self._get_axis_number(axis)
#    3747         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    3748                        sort=sort, group_keys=group_keys, squeeze=squeeze)
#
# /home/xiangrong/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_axis_number(self, axis)
#     313                 pass
#     314         raise ValueError('No axis named {0} for object type {1}'
# ...

# %%
df.groupby(['vendor','err']).sum()
# Out:
#                     pv
# vendor err
# 0       5           11
# 1      -1          960
#         0     36252774
#         1        18030
#         8      1452250
#         9     61448494
#         14    15078438
#         16     1730632
#         20    89694116
#         21     3636738
#         27       25740
#         28   134966787
#         37   127123691
#         43    59599817
#         101  167765347
#         104   34837633
#         105     426477
#         106    1317226
#         151    7680404
#         152   94021328
#         153   25985110
# 2      -1         4803
#         0    482046538
#         8     31660106
#         9      3385027
#         11           1
#         14      594073
#         16   199862589
#         20    96792326
#         21    49293521
# ...                ...
# 61      0       223857
#         4          126
#         8     97707571
#         9        90799
#         37    35784988
#         152   88407772
#         153    2735253
# ...

# %%
df.groupby(['vendor']).sum('pv')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-c26a1f294b9e> in <module>()
# ----> 1 df.groupby(['vendor']).sum('pv')
#
# TypeError: f() takes exactly 1 argument (2 given)

# %%
df[['vendor','pv']
# Out:
#   File "<ipython-input-15-039644bf0cc5>", line 1
#     df[['vendor','pv']
#                       ^
# SyntaxError: unexpected EOF while parsing

# %%
df['vendor','pv']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-c4225c298c04> in <module>()
# ----> 1 df['vendor','pv']
#
# /home/xiangrong/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1990             return self._getitem_multilevel(key)
#    1991         else:
# -> 1992             return self._getitem_column(key)
#    1993
#    1994     def _getitem_column(self, key):
#
# /home/xiangrong/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1997         # get column
#    1998         if self.columns.is_unique:
# -> 1999             return self._get_item_cache(key)
#    2000
#    2001         # duplicate columns & possible reduce dimensionality
#
# /home/xiangrong/anaconda2/lib/python2.7/site-packages/pandas/core/generic.pyc in _get_item_cache(self, item)
# ...

# %%
df.pv
# Out:
# 0        1687849
# 1             11
# 2            215
# 3             43
# 4              2
# 5       88407772
# 6        2735253
# 7            960
# 8       36252774
# 9          18030
# 10             4
# 11       1452250
# 12            41
# 13      61448494
# 14          2031
# 15            10
# 16      15078438
# 17            26
# 18             1
# 19       1730632
# 20      15539845
# 21      89694116
# 22       3636738
# 23      47049900
# 24      35273478
# 25           732
# 26         25740
# 27       5887748
# 28     134966787
# 29          4803
#          ...
# 321        22694
# 322            5
# 323       612180
# 324        87274
# 325           79
# 326     98145428
# 327          358
# 328       223857
# 329          126
# 330     97707571
# 331        90799
# 332    500083547
# 333     32597438
# 334      3673703
# 335     35784988
# 336            4
# 337     11283919
# 338       121450
# 339         3684
# 340     34120684
# 341    480033648
# ...

# %%
df.loc(["vendor","pv"])

# %%
df[['vendor','pv']]
# Out:
#      vendor         pv
# 0        64    1687849
# 1         0         11
# 2        33        215
# 3        33         43
# 4        33          2
# 5        61   88407772
# 6        61    2735253
# 7         1        960
# 8         1   36252774
# 9         1      18030
# 10       33          4
# 11        1    1452250
# 12       63         41
# 13        1   61448494
# 14       63       2031
# 15       63         10
# 16        1   15078438
# 17       34         26
# 18       34          1
# 19        1    1730632
# 20       31   15539845
# 21        1   89694116
# 22        1    3636738
# 23       31   47049900
# 24       31   35273478
# 25       31        732
# 26        1      25740
# 27       31    5887748
# 28        1  134966787
# 29        2       4803
# ..      ...        ...
# 321      27      22694
# 322      27          5
# 323      57     612180
# 324      57      87274
# 325      57         79
# 326      21   98145428
# 327      61        358
# 328      61     223857
# ...

# %%
df[['vendor','pv']].groupby(['vendor']).sum()
# Out:
#                 pv
# vendor
# 0               11
# 1        863061992
# 2       2800098527
# 3        271607660
# 4           474661
# 5        298238532
# 8         31547706
# 9       3166109748
# 10       921307925
# 13         3218257
# 14       204042171
# 15       562506357
# 16       308049372
# 20         1317140
# 21      1965229277
# 24      1503452801
# 27           22703
# 31      1317952939
# 33             264
# 34              27
# 37        56639950
# 38          907002
# 40               5
# 54         2099583
# 56              43
# 57        98163342
# 58        51549866
# 61       224950724
# 63            2082
# 64       254673003
# 68       114382790
# 70       234322848

# %%
errcode=pd.read_table('./errcode',sep='\t',header=None, names=['err','mean','phase'])

# %%
errcode=pd.read_csv('./errcode.csv',header=None)

# %%
errcode
# Out:
#        0                                                  1  \
# 0    104                                              ����ʱ
# 1     37                                      PVһ����Ƶ�ο���
# 2     42                                   appid ����������
# 3     43                                  domain ����������
# 4     44                           slot_id���������ˣ�������
# 5     46                                  domain ����������
# 6     48                               ua ���������ˣ�������
# 7    150                                       δ֪����������
# 8    151                                   Domain����������
# 9    152                                       Ip����������
# 10   153                                      Uid����������
# 11   154                                    APPid����������
# 12   155                                       ��userid����
# 13   157                        (who_server)ʵʱzid����������
# 14   158                        (who_server)ʵʱuid����������
# ...

# %%
errcode.dropna()
# Out:
#        0                                                  1  \
# 0    104                                              ����ʱ
# 1     37                                      PVһ����Ƶ�ο���
# 2     42                                   appid ����������
# 3     43                                  domain ����������
# 4     44                           slot_id���������ˣ�������
# 5     46                                  domain ����������
# 6     48                               ua ���������ˣ�������
# 7    150                                       δ֪����������
# 8    151                                   Domain����������
# 9    152                                       Ip����������
# 10   153                                      Uid����������
# 11   154                                    APPid����������
# 12   155                                       ��userid����
# 13   157                        (who_server)ʵʱzid����������
# 14   158                        (who_server)ʵʱuid����������
# ...

# %%
errcode=errcode.dropna()

# %%
pd.merge(df,errcode,left_on='')

# %%
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-35-91c8ab50676b> in <module>()
# ----> 1 errcode=pd.read_csv('./errcode.csv',header=None,encoding='gbk')
#
# ...

# %%
errcode
# Out:
#        0                                                  1  \
# 0    104                                              ����ʱ
# 1     37                                      PVһ����Ƶ�ο���
# 2     42                                   appid ����������
# 3     43                                  domain ����������
# 4     44                           slot_id���������ˣ�������
# 5     46                                  domain ����������
# 6     48                               ua ���������ˣ�������
# 7    150                                       δ֪����������
# 8    151                                   Domain����������
# 9    152                                       Ip����������
# 10   153                                      Uid����������
# 11   154                                    APPid����������
# 12   155                                       ��userid����
# 13   157                        (who_server)ʵʱzid����������
# 14   158                        (who_server)ʵʱuid����������
# ...

# %%
errcode
# Out:
#                                                                                 err  \
# 104 ����ʱ                                              all                 no    no
# 37  PVһ����Ƶ�ο���                                      argumentor          no    no
# 42  appid ����������                                   argumentor          no    no
# 43  domain ����������                                  argumentor          no    no
# 44  slot_id���������ˣ�������                           argumentor          no    no
# 46  domain ����������                                  argumentor          no    no
# 48  ua ���������ˣ�������                               argumentor          no    no
# 150 δ֪����������                                       argumentor          no    no
# 151 Domain����������                                   argumentor          no    no
# 152 Ip����������                                       argumentor          no    no
# ...

# %%
pd.merge(df,errcode,left_on='err',right_on=0)
# Out:
#      vendor  err         pv    0  \
# 0        64   37    1687849   37
# 1         1   37  127123691   37
# 2         2   37  211030327   37
# 3        68   37    2812302   37
# 4         3   37      75582   37
# 5         4   37       3593   37
# 6        37   37     429485   37
# 7        70   37    3740606   37
# 8         5   37    4785648   37
# 9        38   37        286   37
# 10        8   37      12980   37
# 11        9   37  169609487   37
# 12       10   37    4936225   37
# 13       14   37   58911807   37
# 14       15   37   57999324   37
# 15       20   37       1845   37
# 16       21   37  199222464   37
# 17       24   37   35089288   37
# 18       57   37    2294748   37
# 19       58   37    2984959   37
# 20       61   37   35784988   37
# 21       31   37    4615251   37
# 22        0    5         11    5
# 23       33    1         43    1
# 24        1    1      18030    1
# 25       34    1          1    1
# 26        5    1   15699357    1
# ...

# %%
m=pd.merge(df,errcode,left_on='err',right_on=0)
m
# Out:
#      vendor  err         pv    0  \
# 0        64   37    1687849   37
# 1         1   37  127123691   37
# 2         2   37  211030327   37
# 3        68   37    2812302   37
# 4         3   37      75582   37
# 5         4   37       3593   37
# 6        37   37     429485   37
# 7        70   37    3740606   37
# 8         5   37    4785648   37
# 9        38   37        286   37
# 10        8   37      12980   37
# 11        9   37  169609487   37
# 12       10   37    4936225   37
# 13       14   37   58911807   37
# 14       15   37   57999324   37
# 15       20   37       1845   37
# 16       21   37  199222464   37
# 17       24   37   35089288   37
# 18       57   37    2294748   37
# 19       58   37    2984959   37
# 20       61   37   35784988   37
# 21       31   37    4615251   37
# 22        0    5         11    5
# 23       33    1         43    1
# 24        1    1      18030    1
# 25       34    1          1    1
# 26        5    1   15699357    1
# ...

# %%
pvbyv=m[['vendor','pv']].groupby(['vendor']).sum()

# %%
pvbyp=m[['vendor',2,'pv']].groupby(['vendor',2]).sum()

# %%
pvbyv=m[['vendor','pv']].groupby(['vendor']).sum()

# %%
pvbyv.index
# Out:
# Int64Index([ 0,  1,  2,  3,  4,  5,  8,  9, 10, 13, 14, 15, 16, 20, 21, 24, 27,
#             31, 33, 34, 37, 38, 54, 57, 58, 61, 63, 64, 68, 70],
#            dtype='int64', name=u'vendor')

# %%
pvbyv['vendor']=pvbyv.index

# %%
m.dtypes
# Out:
# vendor     int64
# err        int64
# pv         int64
# 2         object
# dtype: object

# %%
res=pd.merge(m,pvbyv,left_on='vendor',right_on='vendor')

# %%
import numpy as np
pvbyv['vendor']=pvbyv.index
res=pd.merge(m,pvbyv,left_on='vendor',right_on='vendor')
res['ratio']=res['pv_x']/res['pv_y']*100
color_map={"argumentor":"b","router":"g","searcher":"r","before broker":"c","all":"m","broker":"y","yielder":"y","robot":"k"}
phases=["before broker","broker","argumentor","router","searcher","robot","yielder","all"]

color_arr=[]
all_res=pd.DataFrame()
for i in phases:
    t=res[(res['vendor']==1)&(res[2]==i)][['err','ratio']].sort_values(['ratio'],ascending=False).reset_index()[["err","ratio"]]
    num=len(t.to_records())
    all_res=all_res.append(t)
    for j in range(0,num):
        color_arr.append(color_map.get(i))
print all_res    
def autolabel(bars):
    # attach some text labels
    for bar in bars:
        width = bar.get_width()
        ax.text(bar.get_x()+bar.get_width()+5, bar.get_y() + bar.get_height()/2,
                '%0.2f' % float(width)+"%",
                ha='right',va='center')
print color_arr
all_res.index=all_res['err']
fig,ax=plt.subplots()
a=all_res['ratio']*2
print "----",all_res.shape[0]
ind=np.arange(0,0-all_res.shape[0]*4,-4)
width=4
temp=ax.barh(ind,a,width,color=color_arr)
ax.set_yticks(ind+0.5*width)
ax.set_yticklabels(all_res.index)
autolabel(temp)
plt.show()
# Out:
#    err      ratio
# 0  106   0.159319
# 0    1   0.002181
# 1   -1   0.000116
# 0   37  15.375693
# 1  152  11.371941
# 2   43   7.208637
# 3  153   3.142916
# 4  151   0.928950
# 0   28  16.324321
# 0   20  10.848562
# 1   14   1.823747
# 2   21   0.439866
# 3   16   0.209321
# 4    8   0.175651
# 5  105   0.051583
# 0  101  20.291328
# 0    9   7.432235
# 0  104   4.213634
# ['c', 'y', 'y', 'b', 'b', 'b', 'b', 'b', 'g', 'r', 'r', 'r', 'r', 'r', 'r', 'k', 'y', 'm']
# ---- 18

# %%
t

# %%
pt.index=pt[2]

# %%
pt=pt[pt['vendor']==1][['err','ratio']]
res
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-130-10e28df2e490> in <module>()
# ----> 1 pt=pt[pt['vendor']==1][['err','ratio']]
#       2 res
#
# /home/xiangrong/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1990             return self._getitem_multilevel(key)
#    1991         else:
# -> 1992             return self._getitem_column(key)
#    1993
#    1994     def _getitem_column(self, key):
#
# /home/xiangrong/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1997         # get column
#    1998         if self.columns.is_unique:
# -> 1999             return self._get_item_cache(key)
#    2000
#    2001         # duplicate columns & possible reduce dimensionality
#
# ...

# %%
color_map={"argumentor":"b","router":"g","searcher":"r","before broker":"c","all":"m","broker":"y","yielder":"y"}
phases=["before broker","broker","router","searcher","yielder","all"]
# Out:
#                vendor  err       pv_x              2        pv_y      ratio
# 2
# argumentor         64   37    1687849     argumentor   254673003   0.662751
# broker             64    1     216353         broker   254673003   0.084953
# searcher           64    8  227202813       searcher   254673003  89.213545
# broker             64   -1        150         broker   254673003   0.000059
# all                64  104    2270537            all   254673003   0.891550
# before broker      64  106     208459  before broker   254673003   0.081854
# before broker      64  107        860  before broker   254673003   0.000338
# broker             64   98     397018         broker   254673003   0.155893
# router             64   28   19291583         router   254673003   7.575040
# broker             64   99    3397381         broker   254673003   1.334017
# argumentor          1   37  127123691     argumentor   826783478  15.375693
# ...

# %%
pt
# Out:
#                err      ratio
# 2
# argumentor      37  15.375693
# broker           1   0.002181
# searcher         8   0.175651
# argumentor     152  11.371941
# argumentor     153   3.142916
# broker          -1   0.000116
# searcher        20  10.848562
# all            104   4.213634
# yielder          9   7.432235
# before broker  106   0.159319
# searcher        14   1.823747
# searcher        16   0.209321
# searcher        21   0.439866
# robot          101  20.291328
# searcher       105   0.051583
# router          28  16.324321
# argumentor      43   7.208637
# argumentor     151   0.928950

# %%
pt.plot(kind='barh')

# %%
res[res['vendor']==1][['ratio','err']].plot(kind='bar')

# %%
pt=res[res['vendor']==1][['err','ratio']]

# %%
pt.index=pt['err']

# %%
pt['ratio'].plot(kind='barh')

# %%
from numpy import *
test=pd.DataFrame(random.rand(10, 4), columns=['a', 'b', 'c', 'd'])

# %%
test
# Out:
#           a         b         c         d
# 0  0.922117  0.928758  0.229472  0.862797
# 1  0.265331  0.559529  0.218845  0.592514
# 2  0.319607  0.899302  0.236041  0.202472
# 3  0.939659  0.573386  0.668625  0.713054
# 4  0.759320  0.089707  0.486253  0.931506
# 5  0.787665  0.638641  0.757233  0.674363
# 6  0.121648  0.791828  0.845851  0.367688
# 7  0.308727  0.406466  0.249245  0.871849
# 8  0.389852  0.065051  0.071181  0.505900
# 9  0.030360  0.001405  0.788961  0.427691

# %%
res
# Out:
#      vendor  err       pv_x              2        pv_y         ratio
# 0        64   37    1687849     argumentor   254673003  6.627514e-03
# 1        64    1     216353         broker   254673003  8.495325e-04
# 2        64    8  227202813       searcher   254673003  8.921354e-01
# 3        64   -1        150         broker   254673003  5.889906e-07
# 4        64  104    2270537            all   254673003  8.915499e-03
# 5        64  106     208459  before broker   254673003  8.185359e-04
# 6        64  107        860  before broker   254673003  3.376879e-06
# 7        64   98     397018         broker   254673003  1.558932e-03
# 8        64   28   19291583         router   254673003  7.575040e-02
# 9        64   99    3397381         broker   254673003  1.334017e-02
# 10        1   37  127123691     argumentor   826783478  1.537569e-01
# 11        1    1      18030         broker   826783478  2.180740e-05
# 12        1    8    1452250       searcher   826783478  1.756506e-03
# ...

# %%
pvbyv

# %%
pvbyv=
# Out:
# vendor     int64
# err        int64
# pv         int64
# 2         object
# dtype: object

# %%
pvbyv.dtypes
# Out:
# pv    int64
# dtype: object

# %%
pbbyv
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-66-20511e97a4ec> in <module>()
# ----> 1 pbbyv
#
# NameError: name 'pbbyv' is not defined

# %%
m[['vendor',2,'pv']].groupby(['vendor',2]).sum()
# Out:
#                                     pv
# vendor 2
# 0      broker                       11
# 1      all                    34837633
#        argumentor            314410350
#        before broker           1317226
#        broker                    18990
#        robot                 167765347
#        router                134966787
#        searcher              112018651
#        yielder                61448494
# 2      all                   127411936
#        argumentor           1356027768
#        argumentor/searcher   108409547
#        before broker           6904750
#        broker                     4803
#        robot                 325022248
#        searcher              380237100
#        yielder                 3385027
# 3      all                     6790021
#        argumentor            119567270
#        before broker            365695
#        broker                        4
#        router                 14835673
#        searcher              130048997
# ...

# %%
errcode[0]=errcode[0].astype(int)
# Out:
# /var/sdb/home/xiangrong/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
errcode.dtypes
# Out:
# 0     int64
# 1    object
# 2    object
# 3    object
# 4    object
# 5    object
# 6    object
# dtype: object

# %%
errcode.dtypes
# Out:
# 0    object
# 1    object
# 2    object
# 3    object
# 4    object
# 5    object
# 6    object
# dtype: object

# %%
errcode
# Out:
#        0                                                  1  \
# 0    104                                              ����ʱ
# 1     37                                      PVһ����Ƶ�ο���
# 2     42                                   appid ����������
# 3     43                                  domain ����������
# 4     44                           slot_id���������ˣ�������
# 5     46                                  domain ����������
# 6     48                               ua ���������ˣ�������
# 7    150                                       δ֪����������
# 8    151                                   Domain����������
# 9    152                                       Ip����������
# 10   153                                      Uid����������
# 11   154                                    APPid����������
# 12   155                                       ��userid����
# 13   157                        (who_server)ʵʱzid����������
# 14   158                        (who_server)ʵʱuid����������
# ...
